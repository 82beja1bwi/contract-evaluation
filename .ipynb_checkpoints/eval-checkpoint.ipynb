# %%
#imports
import pandas as pd

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('./output.csv')

# Create additional columns
df['diff_2c'] = df['score_granular_2c'] - df['score_binary_2c']
df['diff_3c'] = df['score_granular_3c'] - df['score_binary_3c']

# Define a function to calculate the absolute difference range
def get_diff_abs(diff):
    if diff == 0:
        return "0"
    elif 0 < diff <= 100:
        return "1to100"
    elif 100 < diff <= 500:
        return "101to500"
    elif 500 < diff <= 1000:
        return "501to1000"
    elif 1000 < diff <= 2000:
        return "1001to2000"
    elif diff > 2000:
        return "greaterThan2000"
    else:
        return "invalid"

# Calculate absolute difference ranges
df['diff_2c_abs'] = df['diff_2c'].apply(get_diff_abs)
df['diff_3c_abs'] = df['diff_3c'].apply(get_diff_abs)

# Calculate the relative difference
df['diff_2c_rel'] = round(df['diff_2c']/df['score_binary_2c'],3)
df['diff_3c_rel'] = round(df['diff_3c']/df['score_binary_3c'],3)


# Display the DataFrame (which will be rendered as a table)
df.head()
# Out:
#    u_cost_rel  u_consent_rel  u_content_rel  s_cost_rel  s_consent_rel  \
# 0         0.0            0.1            0.9         0.0            0.1
# 1         0.0            0.1            0.9         0.0            0.2
# 2         0.0            0.1            0.9         0.0            0.3
# 3         0.0            0.1            0.9         0.0            0.4
# 4         0.0            0.1            0.9         0.0            0.5
#
#    s_content_rel  score_binary_2c  score_binary_3c  score_granular_2c  \
# 0            0.9             9000             9000               9025
# 1            0.8             9000             9000               9000
# 2            0.7             9000             9000               9000
# 3            0.6             9000             9000               9000
# 4            0.5             9000             9000               9000
#
#    score_granular_3c  diff_2c  diff_3c diff_2c_abs diff_3c_abs  diff_2c_rel  \
# 0               9025       25       25      1to100      1to100        0.003
# 1               9000        0        0           0           0        0.000
# 2               9000        0        0           0           0        0.000
# 3               9000        0        0           0           0        0.000
# 4               9000        0        0           0           0        0.000
#
#    diff_3c_rel
# 0        0.003
# 1        0.000
# 2        0.000
# 3        0.000
# 4        0.000

# %%
# distribution of absolute differences
# 2C
print('How many points are gained in 2C negotiations?')
print(df['diff_2c_abs'].value_counts())

# 3C
print('\nHow many points are gained in 3C negotiations?')
print(df['diff_3c_abs'].value_counts())
# Out:
# How many points are gained in 2C negotiations?
# 0                  1171
# 1to100              236
# 101to500            200
# 501to1000            60
# 1001to2000           13
# greaterThan2000       1
# Name: diff_2c_abs, dtype: int64
#
# How many points are gained in 3C negotiations?
# 0                  1182
# 1to100              241
# 101to500            198
# 501to1000            46
# 1001to2000           13
# greaterThan2000       1
# Name: diff_3c_abs, dtype: int64

# %%
# distribution of relative differences
import matplotlib.pyplot as plt

print(df['diff_2c_rel'].describe())
print(df['diff_3c_rel'].describe())


# Plot histogram
plt.hist(df['diff_2c_rel'], bins=40, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Relative Score Difference')
plt.ylabel('Frequency')
plt.title('Distribution of Relative Score Difference (diff_2c_rel)')

# Show plot
plt.show()
# Out:
# count    1681.000000
# mean        0.028442
# std         0.109453
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.006000
# max         2.025000
# Name: diff_2c_rel, dtype: float64
# count    1681.000000
# mean        0.018753
# std         0.082854
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.003000
# max         2.025000
# Name: diff_3c_rel, dtype: float64

# %%
# Which are the most commmon combinations of issue relevancies amongst the rows with relative differences > 0.1
df['u_issue_rel'] = df.apply(lambda row: f"{row['u_cost_rel']}-{row['u_consent_rel']}-{row['u_content_rel']}", axis=1)
df['s_issue_rel'] = df.apply(lambda row: f"{row['s_cost_rel']}-{row['s_consent_rel']}-{row['s_content_rel']}", axis=1)
df['issue_rel'] = df.apply(lambda row: f"{row['u_issue_rel']}-{row['s_issue_rel']}", axis=1)

# Print the filtered DataFrame
df.head()
# Out:
#      u_cost_rel  u_consent_rel  u_content_rel  s_cost_rel  s_consent_rel  \
# 210         0.0            0.6            0.4         0.0            0.6
# 226         0.0            0.6            0.4         0.2            0.5
# 240         0.0            0.6            0.4         0.5            0.3
# 252         0.0            0.7            0.3         0.0            0.7
# 253         0.0            0.7            0.3         0.0            0.8
#
#      s_content_rel  score_binary_2c  score_binary_3c  score_granular_2c  \
# 210            0.4             4000             4000               4900
# 226            0.3             3200             5000               3850
# 240            0.2             2000             7000               2450
# 252            0.3             3000             3000               4225
# 253            0.2             3000             3000               3944
#
#      score_granular_3c  diff_2c  diff_3c diff_2c_abs diff_3c_abs  diff_2c_rel  \
# 210               4900      900      900   501to1000   501to1000        0.225
# 226               5330      650      330   501to1000    101to500        0.203
# 240               7000      450        0    101to500           0        0.225
# 252               4225     1225     1225  1001to2000  1001to2000        0.408
# 253               3944      944      944   501to1000   501to1000        0.315
#
#      diff_3c_rel  u_issue_rel  s_issue_rel                issue_rel
# 210        0.225  0.0-0.6-0.4  0.0-0.6-0.4  0.0-0.6-0.4-0.0-0.6-0.4
# 226        0.066  0.0-0.6-0.4  0.2-0.5-0.3  0.0-0.6-0.4-0.2-0.5-0.3
# 240        0.000  0.0-0.6-0.4  0.5-0.3-0.2  0.0-0.6-0.4-0.5-0.3-0.2
# 252        0.408  0.0-0.7-0.3  0.0-0.7-0.3  0.0-0.7-0.3-0.0-0.7-0.3
# 253        0.315  0.0-0.7-0.3  0.0-0.8-0.2  0.0-0.7-0.3-0.0-0.8-0.2

# %%
# user and site give relevancies to issues (3C). 
# Which are the combinations leading to the highest gains of granular negotiation?
filtered_df = df[df['diff_2c_rel']>0.2]

print('most common relevancies by user')
print(filtered_df['u_issue_rel'].value_counts().head(10), '\n')
print('most common relevancies by site')
print(filtered_df['s_issue_rel'].value_counts().head(), '\n')
print('most common combinations of relevancies')
print(filtered_df['issue_rel'].value_counts().head())
# Out:
# most common relevancies by user
# 0.0-0.7-0.3    11
# 0.0-0.8-0.2    11
# 0.1-0.7-0.2    11
# 0.1-0.8-0.1    11
# 0.0-0.9-0.1     9
# 0.0-0.6-0.4     3
# 0.1-0.6-0.3     3
# 0.2-0.6-0.2     3
# Name: u_issue_rel, dtype: int64
#
# most common relevancies by site
# 0.0-0.7-0.3    5
# 0.0-0.8-0.2    5
# 0.0-0.9-0.1    5
# 0.1-0.7-0.2    5
# 0.1-0.8-0.1    5
# Name: s_issue_rel, dtype: int64
#
# most common combinations of relevancies
# 0.0-0.6-0.4-0.0-0.6-0.4    1
# 0.1-0.7-0.2-0.4-0.5-0.1    1
# 0.0-0.9-0.1-0.5-0.4-0.1    1
# 0.1-0.6-0.3-0.0-0.6-0.4    1
# 0.1-0.6-0.3-0.2-0.5-0.3    1
# Name: issue_rel, dtype: int64

# %%
# user and site give relevancies to issues (3C). 
# Which are the combinations leading to the lowest gains (=0) of granular negotiation?
filtered_df = df[df['diff_2c_rel']==0]

print('most common relevancies by user')
print(filtered_df['u_issue_rel'].value_counts().head(40), '\n')
print('most common relevancies by site')
print(filtered_df['s_issue_rel'].value_counts().head(), '\n')
print('most common combinations of relevancies')
print(filtered_df['issue_rel'].value_counts().head())
# Out:
# most common relevancies by user
# 0.0-0.1-0.9    40
# 0.1-0.1-0.8    40
# 0.7-0.1-0.2    40
# 0.6-0.1-0.3    40
# 0.5-0.1-0.4    40
# 0.4-0.1-0.5    40
# 0.3-0.1-0.6    40
# 0.2-0.1-0.7    40
# 0.8-0.1-0.1    40
# 0.5-0.2-0.3    38
# 0.2-0.2-0.6    38
# 0.3-0.2-0.5    38
# 0.4-0.2-0.4    38
# 0.0-0.2-0.8    38
# 0.1-0.2-0.7    38
# 0.6-0.2-0.2    38
# 0.5-0.3-0.2    31
# 0.2-0.3-0.5    31
# 0.4-0.3-0.3    31
# 0.0-0.3-0.7    31
# Name: u_issue_rel, dtype: int64
#
# most common relevancies by site
# 0.2-0.1-0.7    41
# 0.4-0.1-0.5    41
# 0.3-0.1-0.6    41
# 0.1-0.1-0.8    41
# 0.6-0.1-0.3    35
# Name: s_issue_rel, dtype: int64
#
# most common combinations of relevancies
# 0.0-0.1-0.9-0.0-0.2-0.8    1
# 0.4-0.1-0.5-0.5-0.4-0.1    1
# 0.4-0.2-0.4-0.1-0.5-0.4    1
# 0.4-0.2-0.4-0.1-0.4-0.5    1
# 0.4-0.2-0.4-0.1-0.3-0.6    1
# Name: issue_rel, dtype: int64
